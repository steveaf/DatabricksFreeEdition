# %%
# %sql
CREATE CATALOG IF NOT EXISTS demos_standard;
CREATE SCHEMA IF NOT EXISTS demos_standard.demos_bronze;
CREATE SCHEMA IF NOT EXISTS demos_standard.demos_silver;
CREATE SCHEMA IF NOT EXISTS demos_standard.demos_gold;
CREATE SCHEMA IF NOT EXISTS demos_standard.demos_explore;
CREATE SCHEMA IF NOT EXISTS demos_standard.public_data;
