# %%
### https://dbc-811109e0-ad0d.cloud.databricks.com/editor/files/1745910292781958?o=2688516564104003
## /Workspace/Shared/Data/Kaggle/StockMarketData/Google_stock_data.csv

## load the csv file into a dataframe
df = spark.read.csv("/Workspace/Shared/Data/Kaggle/StockMarketData/Google_stock_data.csv", header=True, inferSchema=True)
display(df)
